# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file = "mask_patterns_length10_core1e-05.npz"
mask = np.load(file)["arr_0"]

# %%
print(mask.shape)
# Out:
# (784, 28, 28)

# %%
plt.imshow(mask[0])
