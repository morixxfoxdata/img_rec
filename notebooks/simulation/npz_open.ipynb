# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file = "mask_patterns_length10_core1e-05.npz"
mask = np.load(file)["arr_0"]

# %%
print(mask.shape)
# Out:
# (784, 28, 28)

# %%
plt.imshow(mask[3])

# %%
mask.min()
# Out:
# np.float64(2.5058711924236276e-06)

# %%
mask.max()
# Out:
# np.float64(14.749194064917262)

# %%
mask[3].min()
# Out:
# np.float64(7.33524155556187e-06)

# %%
plt.hist(mask[9])
plt.xlabel("x")
plt.show()
